# %% [markdown]
# <a href="https://colab.research.google.com/github/yuyangweng/Project/blob/main/download_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']='/content/gdrive/My Drive/SIIM-FISABIO-RSNA_COVID-19_Detection'

# %%
# %cd /content/gdrive/My Drive/SIIM-FISABIO-RSNA_COVID-19_Detection
# Out:
# /content/gdrive/My Drive/SIIM-FISABIO-RSNA_COVID-19_Detection

# %%
! ls
# Out:
# download_dataset.ipynb	kaggle.json

# %%
# ! kaggle competitions download -c "siim-covid19-detection"
# Out:
# ...
#  76% 6.00M/7.88M [00:00<00:00, 62.0MB/s]
# 100% 7.88M/7.88M [00:00<00:00, 49.8MB/s]
# ...
#   0% 0.00/930k [00:00<?, ?B/s]
# 100% 930k/930k [00:00<00:00, 52.0MB/s]
# ...
#   0% 0.00/5.10M [00:00<?, ?B/s]
# 100% 5.10M/5.10M [00:00<00:00, 46.7MB/s]
# ...
#  43% 5.00M/11.6M [00:00<00:00, 31.7MB/s]
# 100% 11.6M/11.6M [00:00<00:00, 46.0MB/s]
# ...
# 100% 5.00M/5.00M [00:00<00:00, 28.4MB/s]
# 100% 5.00M/5.00M [00:00<00:00, 23.6MB/s]
# ...
#  94% 9.00M/9.55M [00:00<00:00, 19.8MB/s]
# 100% 9.55M/9.55M [00:00<00:00, 17.7MB/s]
# ...
#  75% 13.0M/17.3M [00:00<00:00, 43.2MB/s]
# 100% 17.3M/17.3M [00:00<00:00, 57.5MB/s]
# ...
#  89% 19.0M/21.3M [00:00<00:00, 48.3MB/s]
# 100% 21.3M/21.3M [00:00<00:00, 83.5MB/s]
# ...
#  57% 9.00M/15.8M [00:00<00:00, 18.4MB/s]
# 100% 15.8M/15.8M [00:00<00:00, 26.8MB/s]
# ...
#  43% 5.00M/11.5M [00:00<00:00, 47.2MB/s]
# 100% 11.5M/11.5M [00:00<00:00, 71.4MB/s]
# ...
#  65% 5.00M/7.72M [00:00<00:00, 18.8MB/s]
# 100% 7.72M/7.72M [00:00<00:00, 25.7MB/s]
# ...
#  85% 7.00M/8.20M [00:00<00:00, 69.6MB/s]
# ...

# %%
! kaggle competitions download -c siim-covid19-detection
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /content/gdrive/My Drive/SIIM-FISABIO-RSNA_COVID-19_Detection. Or use the environment method.

# %%
! ls
# Out:
# 09cf9767a7bf.dcm.zip  5e0e7acd9c7d.dcm.zip  bf1f75117093.dcm.zip
# 0cccb1eca1fc.dcm.zip  6534a837497d.dcm.zip  c39146cbda47.dcm.zip
# 12a2dfb55b6f.dcm.zip  65761e66de9f.dcm.zip  cea591e99b8a.dcm.zip
# 136af218f8df.dcm.zip  695e2c6dede4.dcm.zip  ced40f593496.dcm.zip
# 1df3e98f79be.dcm.zip  6c42a41a6c6e.dcm.zip  dbae9b9b9500.dcm.zip
# 26fa9834387e.dcm.zip  74077a8e3b7c.dcm.zip  download_dataset.ipynb
# 3019399c31f4.dcm.zip  7e7d3afebf5d.dcm.zip  e92b08b5a77c.dcm.zip
# 390ce1f029e7.dcm.zip  92552b44c70c.dcm.zip  f6293b1c49e2.dcm.zip
# 3dcdfc352a06.dcm.zip  951211f8e1bb.dcm.zip  f6ba3df9a8be.dcm.zip
# 3fadf4b48db3.dcm      ad8d4a5ba8f0.dcm.zip  fec0249d70e4.dcm
# 45742200dd51.dcm.zip  ad98af65ad2a.dcm.zip  kaggle.json
# 51635cbfbe18.dcm.zip  af7d1bd1d629.dcm.zip  sample_submission.csv
# 51759b5579bc.dcm.zip  b81969467c6b.dcm.zip  train_image_level.csv.zip
# 53b4af5b74d7.dcm.zip  b98508598396.dcm.zip  train_study_level.csv
# 5af15b21333b.dcm.zip  bb4b1da810f3.dcm.zip
# ...

# %%
import zipfile

for dirname, _, filenames in os.walk("/content/gdrive/My Drive/SIIM-FISABIO-RSNA_COVID-19_Detection"):
    for filename in filenames:
      # if filename[-4:]=='.zip':
      #   zip_ref = zipfile.ZipFile(filename) 
      #   zip_ref.extractall("/content/gdrive/My Drive/SIIM-FISABIO-RSNA_COVID-19_Detection") # extract file to dir
      #   zip_ref.close() 
        os.remove(filename)

# %%
# !ls

# %%
# !wget -x --load-cookies cookies.txt "https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/26680/2283525/compressed/test.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1625115329&Signature=afU5C%2FJICX4tijT9ulSMuUv8rAm561rB9JcrW%2BNI%2BnY6Gb3TqpcjHb5dq%2F1CzipvJS4yIH7u4KCylM3tQRKCqi5NddfedWeKr4lwiCJg%2BZ%2BO4aFHP0megI93B1DwF1cHAaSO5yHcS7DzGZwjlt0qSCryp0o0IYj6my3KYADxyzeINjTXngcajcxJ%2BwRPu1q0xJaKgVcuxPyWg4Y03A8S%2B2MWtcelAUgTXi%2B3oAwg%2B1Sz18ph4d1VzTY2w6iuZmcTvCyfq6%2BdH9EhHbUCjdseTiu6XmORPC%2F0syOiEzMWyKB4yTnhRCULLQWuY7Q4zzMQI%2Fp3ERWcfX13EOv9vxglnw%3D%3D&response-content-disposition=attachment%3B+filename%3Dtest.zip" -O "/content/gdrive/My Drive/SIIM-FISABIO-RSNA_COVID-19_Detection/data.zip"
# Out:
# Cannot open cookies file ‘cookies.txt’: No such file or directory
# --2021-06-28 05:10:16--  https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/26680/2283525/compressed/test.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1625115329&Signature=afU5C%2FJICX4tijT9ulSMuUv8rAm561rB9JcrW%2BNI%2BnY6Gb3TqpcjHb5dq%2F1CzipvJS4yIH7u4KCylM3tQRKCqi5NddfedWeKr4lwiCJg%2BZ%2BO4aFHP0megI93B1DwF1cHAaSO5yHcS7DzGZwjlt0qSCryp0o0IYj6my3KYADxyzeINjTXngcajcxJ%2BwRPu1q0xJaKgVcuxPyWg4Y03A8S%2B2MWtcelAUgTXi%2B3oAwg%2B1Sz18ph4d1VzTY2w6iuZmcTvCyfq6%2BdH9EhHbUCjdseTiu6XmORPC%2F0syOiEzMWyKB4yTnhRCULLQWuY7Q4zzMQI%2Fp3ERWcfX13EOv9vxglnw%3D%3D&response-content-disposition=attachment%3B+filename%3Dtest.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.119.128, 108.177.111.128, 142.250.152.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.119.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
ls
# Out:
# data.zip

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#   inflating: 00188a671292/3eb5a506ccf3/3dcdfc352a06.dcm
#   inflating: 004bd59708be/e7d024ea82d7/c39146cbda47.dcm
#   inflating: 00508faccd39/d39fc1121992/951211f8e1bb.dcm
#   inflating: 006486aa80b2/fe138b3d009e/5e0e7acd9c7d.dcm
#   inflating: 00655178fdfc/2e01129e9043/5b8ee5baa1d5.dcm
#   inflating: 00a81e8f1051/bdc0bb04ae1e/ced40f593496.dcm
#   inflating: 00be7de16711/bfef2920427a/cea591e99b8a.dcm
#   inflating: 00c7a3928f0f/7476c897257c/f6ba3df9a8be.dcm
#   inflating: 00d63957bc3a/07919a1b758c/dbae9b9b9500.dcm
#   inflating: 0107f2d291d6/aba5c3f634b3/695e2c6dede4.dcm
#   inflating: 0154653179fa/021e7fc630b9/51635cbfbe18.dcm
#   inflating: 015f89ec55ea/b44f4716376b/af7d1bd1d629.dcm
#   inflating: 0241bc13eac6/ff4defec6636/0cccb1eca1fc.dcm
#   inflating: 025bfc117ff8/24e9b7ad4e3f/5af15b21333b.dcm
#   inflating: 028abd3504b6/44c8e1a48537/fec0249d70e4.dcm
#   inflating: 02ee3a9820eb/86d5eb6d44df/ad98af65ad2a.dcm
# ...

# %%
ls
# Out:
# 00188a671292/  2d9814778fe6/  5e729ae9ae3c/  91091b14ff14/  c731d74015f8/
# 004bd59708be/  2de1b57b78a5/  5e99801f484c/  9118eeb0ff4e/  c7389760417a/
# 00508faccd39/  2e3ae25addcc/  5ed4ac4c2302/  913836f6e106/  c7787a3cfb14/
# 006486aa80b2/  2e625aa9c04f/  5f04f4c0fa68/  91fd1001ca08/  c783118f9673/
# 00655178fdfc/  2ea214f65500/  5f0e6a9f6f6d/  9260839a059d/  c798ba1c69e1/
# 00a81e8f1051/  2eb19ca07152/  5f14606437b6/  92a0bb576754/  c7c4926465d5/
# 00be7de16711/  2ebd6459c760/  5f46958edec1/  92d320a0719d/  c803c01dfa08/
# 00c7a3928f0f/  2ecc8e52fed2/  5f6bd96b250b/  92e806962d05/  c82731b476d7/
# 00d63957bc3a/  2f26247d5fa4/  5f8b1e975bdf/  93a2b6809c3b/  c849770966c1/
# 0107f2d291d6/  2f45d8909a99/  5fec26943d57/  93b334bb7f73/  c85581436d7c/
# 0154653179fa/  2f6093195a01/  60a72f493074/  94571b6e07ff/  c87c82925501/
# 015f89ec55ea/  2f8d9f7afedb/  611415679b0b/  945c4c4bf174/  c8b7a0ae731e/
# 0241bc13eac6/  2f92655213ca/  6117058c3931/  94637b260217/  c8bd35fb64e1/
# ...

# %%
import zipfile

for dirname, _, filenames in os.walk("/content/gdrive/My Drive/SIIM-FISABIO-RSNA_COVID-19_Detection"):
    for filename in filenames:
      if filename[-4:]!='.dcm':
        print(filename)
        # zip_ref = zipfile.ZipFile(filename) 
        # zip_ref.extractall("/content/gdrive/My Drive/SIIM-FISABIO-RSNA_COVID-19_Detection") # extract file to dir
        # zip_ref.close() 
        # os.remove(filename)
# Out:
# data.zip
